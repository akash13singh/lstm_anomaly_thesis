# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
df = pd.read_csv("../resources/data/yahoo/A1Benchmark/real_9.csv")
df
# Out:
#       timestamp     value  is_anomaly
# 0             1  0.045833           0
# 1             2  0.042778           0
# 2             3  0.038333           0
# 3             4  0.044545           0
# 4             5  0.050833           0
# 5             6  0.056111           0
# 6             7  0.048611           0
# 7             8  0.041667           0
# 8             9  0.040000           0
# 9            10  0.035278           0
# 10           11  0.030556           0
# 11           12  0.023611           0
# 12           13  0.015278           0
# 13           14  0.010556           0
# 14           15  0.006333           0
# 15           16  0.007917           0
# 16           17  0.008788           0
# 17           18  0.009000           0
# 18           19  0.014000           0
# 19           20  0.025000           0
# 20           21  0.041944           0
# 21           22  0.039444           0
# 22           23  0.047222           0
# 23           24  0.034167           0
# ...

# %%
df_values = df.values
timeseries =df_values[:,1]
is_anomaly = df_values[:,1]
type(values)
# Out:
# numpy.ndarray

# %%
type(timeseries)
# Out:
# numpy.ndarray

# %%
train_size = int(len(timeseries) * 0.7)
train, test = timeseries[0:train_size,], timeseries[train_size:len(values),]

# %%
scaler = StandardScaler()
train = scaler.fit_transform(train)
print "Scaler Mean: %f"%(scaler.mean_)
print "Scaler Variance: %f"%(scaler.var_)
print "Scaled Training Data Mean: %f"%(np.mean(train))
print "Scaled Training Data Variance: %f" % (np.var(train))

# %%
import numpy as np

matrix = np.array(
         [[-2,  5,  3,  2],
          [ 9, -6,  5,  1],
          [ 3,  2,  7,  3],
          [-1,  8, -4,  8]])

diags = [matrix[::-1,:].diagonal(i) for i in range(-matrix.shape[0]+1,1)]
print diags
print [ np.mean(arr) for arr in diags]
print np.array([ np.mean(arr) for arr in diags])
# Out:
# [array([-2]), array([9, 5]), array([ 3, -6,  3]), array([-1,  2,  5,  2])]
# [-2.0, 7.0, 0.0, 2.0]
# [-2.  7.  0.  2.]

# %%
import numpy as np

# Alter dimensions as needed
x,y = 3,4

# create a default array of specified dimensions
a = np.arange(x*y).reshape(x,y)
print ty
print
