# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../resources/data/power_data.txt")

# %%
df.head()
# Out:
#     950
# 0   939
# 1   943
# 2   971
# 3  1014
# 4  1041

# %%
df.plot()

# %%
plt.show()

# %%
df.count()
# Out:
# 950    35039
# dtype: int64

# %%
np.save("../resources/data/power_data",df)

# %%
df[:1000].plot()

# %%
for i in range(
